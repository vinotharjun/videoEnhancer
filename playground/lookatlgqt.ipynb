# %%
import sys
import os
sys.path.append("../")
from pathlib import Path
# %load_ext autoreload
# %autoreload 2
from videoview.data import LQGT
from videoview.utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds=LQGT(gt_path=["../datasets/test/HR/"],lq_path=["../datasets/test/LRx2-compressed/"],scale=2)
a=ds[0]

# %%
save_animation(a[0],"./animation_lr")

# %%
save_animation(a[1],"./animation_hr")

# %%
def f(a,**kwargs):
    print(a,kwargs)
f(1,**{'e': 1})
# Out:
# 1 {'e': 1}

# %%
# Out:
# 1 {'e': 1}
